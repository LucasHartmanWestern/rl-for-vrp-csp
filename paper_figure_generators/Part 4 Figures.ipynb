# %%
import sys
import os
sys.path.append(os.path.abspath('../'))

from evaluation import *
from data_loader import *
import random
from datetime import datetime

# %%
colors = {
    "DQN": 'darkorange',
    "REINFORCE": 'forestgreen',
    "CMA": 'cyan',
    "ODT": 'blueviolet'
}

# %%
starting_exp = 4180
ending_exp = 4188
save_processed_data = True
# exp_lists_preformatted = [
#     '4000_4017.csv', '4018_4035.csv', '5000_5017.csv', '5018_5035.csv', '6000_6017.csv', '6018_6035.csv', # DQN
#     '4036_4053.csv', '4054_4071.csv', '5036_5053.csv', '5054_5071.csv', '6036_6053.csv', '6054_6071.csv', # REINFORCE
#     '4072_4089.csv', '4090_4107.csv', '5072_5089.csv', '5090_5107.csv', '6072_6089.csv', '6090_6107.csv', # CMA
#     '4108_4125.csv', '4126_4143.csv', '5108_5125.csv', '5126_5143.csv', '6108_6125.csv', '6126_6143.csv', # ODT 1
#     '4144_4161.csv', '4162_4179.csv', '5144_5161.csv', '5162_5179.csv', '6144_6161.csv', '6162_6179.csv' # ODT 2
# ] # Existing formatted datasets
exp_lists_preformatted = [
    '4000_4179.csv', '5000_5179.csv', '6000_6179.csv', '4108_4179.csv', '5108_5179.csv', '6108_6179.csv'
] # Existing formatted datasets
# exp_lists_preformatted = []

# TODO: REMOVE THIS!!
# index = 5
# starting_exp = int(exp_lists_preformatted[index].split("_")[0])
# ending_exp = int(exp_lists_preformatted[index].split("_")[1].split('.')[0])

# exp_lists_preformatted = []

# print(f"Running for experiments {starting_exp} to {ending_exp}")

# %%
load_agent = True
load_station = True

target_agg_count = 10
target_reward_type = 'greedy'

exp_agent_data = []
exp_station_data = []

experiments = range(starting_exp, ending_exp + 1)

def load_episode_from_csv(filepath, columns=None, target_ep=999, target_agg=9, chunksize=100_000):   
    filtered_chunks = []
    for chunk in pd.read_csv(filepath, usecols=columns, chunksize=chunksize):
        sel = (chunk['episode'] == target_ep) & (chunk['aggregation'] == target_agg)
        if sel.any():
            filtered_chunks.append(chunk.loc[sel])
    if filtered_chunks:
        return pd.concat(filtered_chunks, ignore_index=True)
    else:
        return pd.DataFrame(columns=columns or [])


if len(exp_lists_preformatted) == 0:
    for ind, exp_num in enumerate(experiments):
        config_fname = f'./Exp_{exp_num}/config.yaml'
        
        c = load_config_file(config_fname)
        nn_c = c['nn_hyperparameters']
        federated_c = c['federated_learning_settings']
        algo_c = c['algorithm_settings']
        env_c = c['environment_settings']
        
        if federated_c['aggregation_count'] != target_agg_count:
            print(f"Experiment {exp_num} does not have matching aggregation level")
            continue

        rtype = 'communal' if nn_c['average_rewards_when_training'] else 'greedy'
        if rtype != target_reward_type:
            print(f"Experiment {exp_num} does not have matching reward type")
            continue
        
        seed = env_c['seed']
        algorithm_dm = algo_c['algorithm']
        
        d_base = f"../../../../storage_1/metrics/Exp_{exp_num}"
        if not os.path.exists(d_base):
            d_base = f"../metrics/Exp_{exp_num}"
        base_path = f"{d_base}/train/metrics"

        print(f'Loading {base_path}.csv')
        # --- AGENT METRICS ---
        if load_agent:
            cols = [
                'episode', 'timestep', 'done', 'zone', 
                'aggregation', 'reward', 'agent_index',
                'distance', 'average_battery'
            ]
            try:
                agent_data = load_episode_from_csv(
                    f'{base_path}_agent_metrics.csv',
                    columns=cols,
                    target_ep=395 if algo_c['algorithm'] == 'ODT' else 999
                )
            except Exception as e:
                agent_data = None
                
            if agent_data is None or agent_data.empty:
                print(f"No agent data for ep=10000 in Exp {exp_num}")
            else:
                agent_data['seed'] = seed
                agent_data['exp_num'] = exp_num
                agent_data['algorithm'] = algorithm_dm
                agent_data['season'] = env_c['season']
                exp_agent_data.append(agent_data)

        # --- STATION METRICS ---
        if load_station:
            cols = [
                'episode', 'timestep', 'done', 'zone',
                'aggregation', 'station_index', 'traffic'
            ]
            try:
                station_data = load_episode_from_csv(
                    f'{base_path}_station_metrics.csv',
                    columns=cols,
                    target_ep=395 if algo_c['algorithm'] == 'ODT' else 999
                )
            except Exception as e:
                station_data = None
                
            if station_data is None or station_data.empty:
                print(f"No station data for ep=10000 in Exp {exp_num}")
            else:
                station_data['seed'] = seed
                station_data['exp_num'] = exp_num
                station_data['algorithm'] = algorithm_dm
                station_data['season'] = env_c['season']
                exp_station_data.append(station_data)

# %%
if len(exp_lists_preformatted) == 0:
    # Convert data to DataFrame for easier manipulation
    if load_agent:
        df_agent = pd.concat(exp_agent_data, ignore_index=True)

        cumulative_agent_df = (
            df_agent
            .groupby(
                ['episode', 'zone', 'aggregation', 'agent_index', 'seed', 'exp_num', 'algorithm', 'season']
            )[['distance', 'average_battery', 'reward']]
            .sum()
            .reset_index()
        )

        # Rename the 'reward' column to 'cumulative_reward' for clarity
        cumulative_agent_df.rename(columns={'average_battery': 'battery_used'}, inplace=True)
        cumulative_agent_df.rename(columns={'distance': 'distance_traveled'}, inplace=True)
        
        cumulative_agent_df['episode'] = cumulative_agent_df['aggregation'] * (10000/target_agg_count) + cumulative_agent_df['episode']
    
    if load_station:
        df_station = pd.concat(exp_station_data, ignore_index=True)
    
        print('Cumulating data')    
        cumulative_station_df = (
            df_station
            .groupby(
                ['episode', 'zone', 'aggregation', 'station_index', 'seed', 'exp_num', 'algorithm', 'season']
            )[['traffic']]
            .max()
            .reset_index()
        )

        print('Recalculating episode')    
        # Get recalculated episodes using (aggregation number * episodes per aggregation) + episode number
        cumulative_station_df['episode'] = cumulative_station_df['aggregation'] * (10000/target_agg_count)  + cumulative_station_df['episode']

# %%
# Define the file path with starting_exp and ending_exp variables
file_path_for_processed_data = f'../../../../storage_1/metrics/formatted_experiment_data/part_4/'

if len(exp_lists_preformatted) == 0:

    # Get the data for the last episode only
    if load_agent:
        cumulative_agent_df = cumulative_agent_df[cumulative_agent_df['episode'] == cumulative_agent_df['episode'].max()]
    
    if load_station:
        cumulative_station_df = cumulative_station_df[cumulative_station_df['episode'] == cumulative_station_df['episode'].max()]

    
    if save_processed_data:
        if not os.path.exists(file_path_for_processed_data):
            os.makedirs(file_path_for_processed_data)
        
        # Save the DataFrame to a CSV file
        if load_agent:
            cumulative_agent_df.to_csv(f"{file_path_for_processed_data}/agent_{starting_exp}_{ending_exp}.csv", index=False)
            print(f"Data successfully saved to {file_path_for_processed_data}/agent_{starting_exp}_{ending_exp}.csv")

        if load_station:
            cumulative_station_df.to_csv(f"{file_path_for_processed_data}/station_{starting_exp}_{ending_exp}.csv", index=False)
            print(f"Data successfully saved to {file_path_for_processed_data}/station_{starting_exp}_{ending_exp}.csv")

if len(exp_lists_preformatted) > 0:
    if load_agent:
        agent_dataframes = []
        
        # Load and combine datasets
        for existing_set in exp_lists_preformatted:
            loaded_dataset = pd.read_csv(f"{file_path_for_processed_data}/agent_{existing_set}")
            # Combine datasets
            agent_dataframes.append(loaded_dataset)
    
        cumulative_agent_df = pd.concat(agent_dataframes, ignore_index=True)

    if load_station:
        station_dataframes = []
        
        # Load and combine datasets
        for existing_set in exp_lists_preformatted:
            loaded_dataset = pd.read_csv(f"{file_path_for_processed_data}/station_{existing_set}")
            # Combine datasets
            station_dataframes.append(loaded_dataset)
    
        cumulative_station_df = pd.concat(station_dataframes, ignore_index=True)

# %%
# Determine list of algorithms
if load_agent:
    algos = cumulative_agent_df['algorithm'].unique()
elif load_station:
    algos = cumulative_station_df['algorithm'].unique()
else:
    algos = []

# Determine list of seasons (only needed if load_agent or load_station)
seasons = None
if load_agent and 'season' in cumulative_agent_df:
    seasons = sorted(cumulative_agent_df['season'].unique())
elif load_station and 'season' in cumulative_station_df:
    seasons = sorted(cumulative_station_df['season'].unique())

for algo in algos:
    print(f"===== Algorithm: {algo} =====\n")
    # --- Overall metrics ---
    if load_agent:
        agent_d = cumulative_agent_df[cumulative_agent_df['algorithm'] == algo]
        print("  Agent metrics (overall):")
        print(f"    Avg Distance Travelled: {agent_d['distance_traveled'].mean():.2f}")
        print(f"    Distance Std Dev      : {agent_d['distance_traveled'].std():.2f}")
        print(f"    Avg Battery Used (Wh) : {agent_d['battery_used'].mean():.2f}")
        print(f"    Battery Std Dev (Wh)  : {agent_d['battery_used'].std():.2f}")
        print(f"    Avg Reward            : {agent_d['reward'].mean():.2f}")
        print(f"    Reward Std Dev        : {agent_d['reward'].std():.2f}\n")

    if load_station:
        station_d = cumulative_station_df[cumulative_station_df['algorithm'] == algo]
        print("  Station metrics (overall):")
        print(f"    Max Traffic           : {station_d['traffic'].max():.2f}")
        print(f"    Traffic Std Dev       : {station_d['traffic'].std():.2f}\n")

    # --- Metrics by season ---
    if seasons is not None:
        for season in seasons:
            print(f"  Season: {season}")
            if load_agent:
                a_season = cumulative_agent_df[
                    (cumulative_agent_df['algorithm'] == algo) &
                    (cumulative_agent_df['season'] == season)
                ]
                if not a_season.empty:
                    print("    Agent:")
                    print(f"      Avg Distance : {a_season['distance_traveled'].mean():.2f}")
                    print(f"      Dist Std Dev : {a_season['distance_traveled'].std():.2f}")
                    print(f"      Avg Battery Used (Wh)  : {a_season['battery_used'].mean():.2f}")
                    print(f"      Batt Std Dev (Wh) : {a_season['battery_used'].std():.2f}")
                    print(f"      Avg Reward   : {a_season['reward'].mean():.2f}")
                    print(f"      Reward Std   : {a_season['reward'].std():.2f}")

            if load_station:
                s_season = cumulative_station_df[
                    (cumulative_station_df['algorithm'] == algo) &
                    (cumulative_station_df['season'] == season)
                ]
                if not s_season.empty:
                    print("    Station:")
                    print(f"      Max Traffic   : {s_season['traffic'].max():.2f}")
                    print(f"      Traffic Std   : {s_season['traffic'].std():.2f}")
            print()  # blank line between seasons

    print("\n")  # extra space between algorithms
# Out:
# ===== Algorithm: DQN =====
#
#   Agent metrics (overall):
#     Avg Distance Travelled: 37.12
#     Distance Std Dev      : 1.53
#     Avg Battery Used (Wh) : 19379.10
#     Battery Std Dev (Wh)  : 4216.08
#     Avg Reward            : -64.13
#     Reward Std Dev        : 6.32
#
#   Station metrics (overall):
#     Max Traffic           : 26.00
#     Traffic Std Dev       : 2.03
#
#   Season: autumn
#     Agent:
#       Avg Distance : 37.11
#       Dist Std Dev : 1.52
#       Avg Battery Used (Wh)  : 21325.77
#       Batt Std Dev (Wh) : 3103.67
#       Avg Reward   : -63.29
#       Reward Std   : 6.06
#     Station:
#       Max Traffic   : 26.00
#       Traffic Std   : 2.03
#
#   Season: spring
#     Agent:
#       Avg Distance : 37.12
#       Dist Std Dev : 1.52
#       Avg Battery Used (Wh)  : 17572.16
#       Batt Std Dev (Wh) : 3155.58
#       Avg Reward   : -64.55
#       Reward Std   : 6.17
#     Station:
#       Max Traffic   : 26.00
#       Traffic Std   : 2.03
#
#   Season: summer
#     Agent:
#       Avg Distance : 37.11
#       Dist Std Dev : 1.52
#       Avg Battery Used (Wh)  : 22786.93
#       Batt Std Dev (Wh) : 3075.07
#       Avg Reward   : -62.89
#       Reward Std   : 6.04
#     Station:
#       Max Traffic   : 26.00
#       Traffic Std   : 2.02
#
#   Season: winter
#     Agent:
#       Avg Distance : 37.14
#       Dist Std Dev : 1.55
#       Avg Battery Used (Wh)  : 15831.54
#       Batt Std Dev (Wh) : 3287.53
#       Avg Reward   : -65.78
#       Reward Std   : 6.59
#     Station:
#       Max Traffic   : 26.00
#       Traffic Std   : 2.05
#
#
#
# ===== Algorithm: REINFORCE =====
#
#   Agent metrics (overall):
#     Avg Distance Travelled: 36.71
#     Distance Std Dev      : 0.94
#     Avg Battery Used (Wh) : 19387.79
#     Battery Std Dev (Wh)  : 4213.70
#     Avg Reward            : -63.35
#     Reward Std Dev        : 4.04
#
#   Station metrics (overall):
#     Max Traffic           : 25.00
#     Traffic Std Dev       : 1.92
#
#   Season: autumn
#     Agent:
#       Avg Distance : 36.70
#       Dist Std Dev : 0.92
#       Avg Battery Used (Wh)  : 21198.31
#       Batt Std Dev (Wh) : 3006.10
#       Avg Reward   : -62.49
#       Reward Std   : 3.42
#     Station:
#       Max Traffic   : 25.00
#       Traffic Std   : 1.91
#
#   Season: spring
#     Agent:
#       Avg Distance : 36.71
#       Dist Std Dev : 0.93
#       Avg Battery Used (Wh)  : 18520.81
#       Batt Std Dev (Wh) : 3696.46
#       Avg Reward   : -64.43
#       Reward Std   : 4.00
#     Station:
#       Max Traffic   : 25.00
#       Traffic Std   : 1.93
#
#   Season: summer
#     Agent:
#       Avg Distance : 36.70
#       Dist Std Dev : 0.91
#       Avg Battery Used (Wh)  : 22543.93
#       Batt Std Dev (Wh) : 2927.18
#       Avg Reward   : -61.57
#       Reward Std   : 3.71
#     Station:
#       Max Traffic   : 23.00
#       Traffic Std   : 1.88
#
#   Season: winter
#     Agent:
#       Avg Distance : 36.73
#       Dist Std Dev : 0.99
#       Avg Battery Used (Wh)  : 15288.12
#       Batt Std Dev (Wh) : 2993.39
#       Avg Reward   : -64.92
#       Reward Std   : 4.05
#     Station:
#       Max Traffic   : 24.00
#       Traffic Std   : 1.96
#
#
#
# ===== Algorithm: CMA =====
#
#   Agent metrics (overall):
#     Avg Distance Travelled: 36.89
#     Distance Std Dev      : 1.28
#     Avg Battery Used (Wh) : 19497.31
#     Battery Std Dev (Wh)  : 4147.11
#     Avg Reward            : -73.73
#     Reward Std Dev        : 5.66
#
#   Station metrics (overall):
#     Max Traffic           : 26.00
#     Traffic Std Dev       : 2.04
#
#   Season: autumn
#     Agent:
#       Avg Distance : 36.87
#       Dist Std Dev : 1.26
#       Avg Battery Used (Wh)  : 21546.68
#       Batt Std Dev (Wh) : 3048.11
#       Avg Reward   : -72.66
#       Reward Std   : 5.38
#     Station:
#       Max Traffic   : 26.00
#       Traffic Std   : 2.02
#
#   Season: spring
#     Agent:
#       Avg Distance : 36.88
#       Dist Std Dev : 1.27
#       Avg Battery Used (Wh)  : 17950.97
#       Batt Std Dev (Wh) : 3194.71
#       Avg Reward   : -74.44
#       Reward Std   : 5.65
#     Station:
#       Max Traffic   : 26.00
#       Traffic Std   : 2.06
#
#   Season: summer
#     Agent:
#       Avg Distance : 36.89
#       Dist Std Dev : 1.28
#       Avg Battery Used (Wh)  : 22908.79
#       Batt Std Dev (Wh) : 2962.42
#       Avg Reward   : -71.77
#       Reward Std   : 5.31
#     Station:
#       Max Traffic   : 24.00
#       Traffic Std   : 1.98
#
#   Season: winter
#     Agent:
#       Avg Distance : 36.90
#       Dist Std Dev : 1.31
#       Avg Battery Used (Wh)  : 15961.86
#       Batt Std Dev (Wh) : 3186.76
#       Avg Reward   : -75.83
#       Reward Std   : 5.42
#     Station:
#       Max Traffic   : 26.00
#       Traffic Std   : 2.09
#
#
#
# ===== Algorithm: ODT =====
#
#   Agent metrics (overall):
#     Avg Distance Travelled: 36.88
#     Distance Std Dev      : 1.19
#     Avg Battery Used (Wh) : 19223.17
#     Battery Std Dev (Wh)  : 4174.47
#     Avg Reward            : -62.22
#     Reward Std Dev        : 4.80
#
#   Station metrics (overall):
#     Max Traffic           : 26.00
#     Traffic Std Dev       : 1.97
#
#   Season: autumn
#     Agent:
#       Avg Distance : 36.88
#       Dist Std Dev : 1.19
#       Avg Battery Used (Wh)  : 21198.23
#       Batt Std Dev (Wh) : 3009.29
#       Avg Reward   : -61.55
#       Reward Std   : 4.70
#     Station:
#       Max Traffic   : 25.00
#       Traffic Std   : 1.96
#
#   Season: spring
#     Agent:
#       Avg Distance : 36.88
#       Dist Std Dev : 1.19
#       Avg Battery Used (Wh)  : 17573.25
#       Batt Std Dev (Wh) : 3151.81
#       Avg Reward   : -62.48
#       Reward Std   : 4.74
#     Station:
#       Max Traffic   : 26.00
#       Traffic Std   : 1.95
#
#   Season: summer
#     Agent:
#       Avg Distance : 36.88
#       Dist Std Dev : 1.18
#       Avg Battery Used (Wh)  : 22543.25
#       Batt Std Dev (Wh) : 2928.91
#       Avg Reward   : -61.10
#       Reward Std   : 4.49
#     Station:
#       Max Traffic   : 25.00
#       Traffic Std   : 1.96
#
#   Season: winter
#     Agent:
#       Avg Distance : 36.90
#       Dist Std Dev : 1.23
#       Avg Battery Used (Wh)  : 15365.26
#       Batt Std Dev (Wh) : 3034.30
#       Avg Reward   : -63.80
#       Reward Std   : 4.82
#     Station:
#       Max Traffic   : 26.00
#       Traffic Std   : 2.01

# %%
if load_agent:
    algos = cumulative_agent_df['algorithm'].unique()
if load_station:
    algos = cumulative_station_df['algorithm'].unique()

for algo in algos:
    print(f"===== Algorithm: {algo} =====")

    if load_agent:
        agent_d = cumulative_agent_df[cumulative_agent_df['algorithm'] == algo]
        print(f"\tAverage Distance Travelled: {agent_d['distance_traveled'].mean():.2f}")
        print(f"\tDistance Travelled Std Dev: {agent_d['distance_traveled'].std():.2f}")
        print(f"\t--")
        print(f"\tAverage Battery Used (Wh): {agent_d['battery_used'].mean():.2f}")
        print(f"\tBattery Used Std Dev (Wh): {agent_d['battery_used'].std():.2f}")
        print(f"\t--")
        print(f"\tAverage Reward: {agent_d['reward'].mean():.2f}")
        print(f"\tReward Std Dev: {agent_d['reward'].std():.2f}")
        print(f"\t--")
    if load_station:
        station_d = cumulative_station_df[cumulative_station_df['algorithm'] == algo]
        print(f"\tMax Traffic: {station_d['traffic'].max():.2f}")
        #print(f"\tTraffic Std Dev: {station_d['traffic'].std():.2f}")

if load_agent:
    print("\n\n")
    for season in cumulative_agent_df['season'].unique():
        season_data = cumulative_agent_df[cumulative_agent_df['season'] == season]
        
        for algo in season_data['algorithm'].unique():
            algo_data = season_data[season_data['algorithm'] == algo]
    
            avg_energy_used = algo_data['battery_used'].mean()
            std_energy_used = algo_data['battery_used'].std()
    
            print(f"Algorotim: {algo} - Season: {season} \
            - Avg. Energy {(avg_energy_used / 100):.2f} - Std. Energy {(std_energy_used / 100):.2f}")
# Out:
# ===== Algorithm: DQN =====
# 	Average Distance Travelled: 37.12
# 	Distance Travelled Std Dev: 1.53
# 	--
# 	Average Battery Used (Wh): 19379.10
# 	Battery Used Std Dev (Wh): 4216.08
# 	--
# 	Average Reward: -64.13
# 	Reward Std Dev: 6.32
# 	--
# 	Max Traffic: 26.00
# ===== Algorithm: REINFORCE =====
# 	Average Distance Travelled: 36.71
# 	Distance Travelled Std Dev: 0.94
# 	--
# 	Average Battery Used (Wh): 19387.79
# 	Battery Used Std Dev (Wh): 4213.70
# 	--
# 	Average Reward: -63.35
# 	Reward Std Dev: 4.04
# 	--
# 	Max Traffic: 25.00
# ===== Algorithm: CMA =====
# 	Average Distance Travelled: 36.89
# 	Distance Travelled Std Dev: 1.28
# 	--
# 	Average Battery Used (Wh): 19497.31
# 	Battery Used Std Dev (Wh): 4147.11
# 	--
# 	Average Reward: -73.73
# 	Reward Std Dev: 5.66
# 	--
# 	Max Traffic: 26.00
# ===== Algorithm: ODT =====
# 	Average Distance Travelled: 36.88
# 	Distance Travelled Std Dev: 1.19
# 	--
# 	Average Battery Used (Wh): 19223.17
# 	Battery Used Std Dev (Wh): 4174.47
# 	--
# 	Average Reward: -62.22
# 	Reward Std Dev: 4.80
# 	--
# 	Max Traffic: 26.00
#
#
#
# Algorotim: DQN - Season: spring             - Avg. Energy 175.72 - Std. Energy 31.56
# Algorotim: REINFORCE - Season: spring             - Avg. Energy 185.21 - Std. Energy 36.96
# Algorotim: CMA - Season: spring             - Avg. Energy 179.51 - Std. Energy 31.95
# Algorotim: ODT - Season: spring             - Avg. Energy 175.73 - Std. Energy 31.52
# Algorotim: DQN - Season: winter             - Avg. Energy 158.32 - Std. Energy 32.88
# Algorotim: REINFORCE - Season: winter             - Avg. Energy 152.88 - Std. Energy 29.93
# Algorotim: CMA - Season: winter             - Avg. Energy 159.62 - Std. Energy 31.87
# Algorotim: ODT - Season: winter             - Avg. Energy 153.65 - Std. Energy 30.34
# Algorotim: DQN - Season: autumn             - Avg. Energy 213.26 - Std. Energy 31.04
# Algorotim: REINFORCE - Season: autumn             - Avg. Energy 211.98 - Std. Energy 30.06
# Algorotim: CMA - Season: autumn             - Avg. Energy 215.47 - Std. Energy 30.48
# Algorotim: ODT - Season: autumn             - Avg. Energy 211.98 - Std. Energy 30.09
# Algorotim: DQN - Season: summer             - Avg. Energy 227.87 - Std. Energy 30.75
# Algorotim: REINFORCE - Season: summer             - Avg. Energy 225.44 - Std. Energy 29.27
# Algorotim: CMA - Season: summer             - Avg. Energy 229.09 - Std. Energy 29.62
# Algorotim: ODT - Season: summer             - Avg. Energy 225.43 - Std. Energy 29.29
